# %% [markdown]
# # Implementation of scaler and ols

# %%
import pandas as pd  # read the data
import numpy as np   # 
import matplotlib.pyplot as plt #   
import seaborn as sns # visualization
# %matplotlib inline

# %%
df = pd.read_csv('student_height_weight.csv')

# %%
df.head()
# Out:
#    Height_cm  Weight_kg
# 0      170.0       64.3
# 1      163.6       66.7
# 2      171.5       73.0
# 3      180.2       72.6
# 4      162.7       43.5

# %%
# scatter plot
plt.scatter(df['Height_cm'],df['Weight_kg'])
plt.xlabel("Height_cm")
plt.ylabel("Weight_kg")
# Out:
# Text(0, 0.5, 'Weight_kg')

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#            Height_cm  Weight_kg
# Height_cm   1.000000   0.095141
# Weight_kg   0.095141   1.000000

# %%
sns.pairplot(df)

# %%
# Independent and dependent features

# %%
df.head()
# Out:
#    Height_cm  Weight_kg
# 0      170.0       64.3
# 1      163.6       66.7
# 2      171.5       73.0
# 3      180.2       72.6
# 4      162.7       43.5

# %%
x = df['Weight_kg']
x
# Out:
# 0      64.3
# 1      66.7
# 2      73.0
# 3      72.6
# 4      43.5
#        ...
# 195    54.4
# 196    39.4
# 197    76.2
# 198    58.6
# 199    74.9
# Name: Weight_kg, Length: 200, dtype: float64

# %%
x = df[['Weight_kg']] # independent features should be data frame or 2d array
x
np.array(x)  # shape (200 ,1) here 1 bcz 2d array
# Out:
# array([[ 64.3],
#        [ 66.7],
#        [ 73. ],
#        [ 72.6],
#        [ 43.5],
#        [ 48.7],
#        [ 66.2],
#        [ 66.2],
#        [ 66.2],
#        [106.2],
#        [ 66.9],
#        [ 73.6],
#        [ 71.4],
#        [ 67.8],
#        [ 56.2],
#        [ 69.1],
#        [ 50.7],
#        [ 57.2],
#        [ 54.2],
#        [ 61. ],
#        [ 87.8],
#        [ 37.6],
#        [ 68.2],
#        [ 40.6],
#        [ 54.3],
#        [ 73.1],
#        [ 60.8],
#        [ 47.1],
#        [ 51.4],
#        [ 68.2],
#        [ 51.2],
#        [ 62.6],
#        [ 60.5],
#        [ 52.2],
#        [ 85.7],
#        [ 67.6],
#        [ 35.7],
#        [ 62.2],
#        [ 52.1],
#        [ 70.2],
#        [ 50.5],
#        [ 58.6],
#        [ 66.1],
#        [ 70.4],
#        [ 45.6],
#        [ 56. ],
#        [ 54.3],
#        [ 52.2],
#        [ 81.2],
#        [ 64.9],
#        [ 44.9],
#        [ 71. ],
#        [ 85.5],
#        [ 72.4],
#        [ 41.8],
# ...

# %%
y = df['Height_cm'] #this variable can be in series or 1d array form
y
# Out:
# 0      170.0
# 1      163.6
# 2      171.5
# 3      180.2
# 4      162.7
#        ...
# 195    168.9
# 196    156.2
# 197    166.5
# 198    165.6
# 199    153.6
# Name: Height_cm, Length: 200, dtype: float64

# %%
np.array(y).shape
# Out:
# (200,)

# %%
# Train and Test split 
# Train data only use for trainning puropose
# Test data only use for prdicting the new data point

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test=train_test_split(x,y,test_size=0.25, random_state=50)

# %%
x_train.shape
# Out:
# (150, 1)

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit_transform(x_train)
# Out:
# array([[ 0.51182892],
#        [ 0.63825499],
#        [-0.88728625],
#        [ 0.17469273],
#        [ 0.04826666],
#        [ 1.73394759],
#        [ 2.16379623],
#        [ 0.50340051],
#        [-0.11187302],
#        [-0.83671582],
#        [ 1.27038534],
#        [ 1.84351685],
#        [ 0.14940752],
#        [-0.87885785],
#        [ 0.19154954],
#        [-0.76928859],
#        [ 1.49795226],
#        [-1.04742594],
#        [ 0.27583359],
#        [ 0.44440168],
#        [-0.069731  ],
#        [-0.65971933],
#        [-0.37315357],
#        [-1.78912555],
#        [-0.18772867],
#        [ 0.74782425],
#        [-1.06428275],
#        [-1.38456212],
#        [ 0.56239935],
#        [ 1.80137483],
#        [-0.16244345],
#        [ 0.77310946],
#        [-1.94083683],
#        [ 1.00910479],
#        [ 0.64668339],
#        [-0.63443411],
#        [ 1.41366821],
#        [-0.52486485],
#        [-0.17087186],
#        [ 0.4696869 ],
#        [ 0.73096744],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.78153787],
#        [-0.45743761],
#        [ 0.90796394],
#        [-0.04444579],
#        [-0.53329326],
#        [ 2.2902223 ],
#        [ 1.2029581 ],
#        [ 0.4696869 ],
#        [ 0.80682308],
#        [ 0.23369157],
#        [ 0.61296977],
#        [ 1.31252736],
#        [ 0.08198028],
#        [ 0.4696869 ],
#        [ 1.05124682],
#        [ 0.58768456],
#        [ 1.43895343],
#        [-1.68798469],
#        [ 0.36854604],
#        [-0.88728625],
#        [-0.68500454],
#        [ 1.54852269],
#        [-0.53329326],
#        [ 2.1216542 ],
#        [-0.38158197],
#        [-1.30870648],
#        [-0.65129092],
#        [ 2.1132258 ],
#        [ 0.25897678],
#        [-0.03601738],
#        [ 2.06265537],
#        [-0.34786835],
#        [ 0.41068806],
#        [ 0.81525149],
#        [-0.36472516],
#        [-0.27201271],
#        [-1.08956796],
#        [-1.58684384],
#        [-1.28342127],
#        [ 0.06512347],
#        [-0.02758898],
# ...

# %% [markdown]
# # Apply Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Coefficient or slope:",regression.coef_)
print("Intercept:",regression.intercept_)
# Out:
# Coefficient or slope: [0.08448052]
# Intercept: 159.14283801924586

# %%
# Plot Training data plot best fit line

# %%
# Prediction for test data

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,regression.predict(x_train),color='black')

# %%
# Prediction for test data

# %%
y=regression.predict(x_test)
# Out:
# C:\Users\porwa\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# performancfrom sklearn Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
mse=mean_squared_error(y_test,x)
mae=mean_absolute_error(y_test,x)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 123.70019878595775
# 9.086599089755012
# 11.122059107285743

# %%
# R square
# Formula
# R^2=1-SSR/SSt
# R^2=coefficient of determination SSR=sum of squares of residulas SSt=total sum of squares

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
print(score)
# Out:
# -0.49950329531330184

# %%
# formula od Adjusted R^2
 # 1-[(1-R^2)*(n-1)/(n-k-1)]

# %%
# Adjusted R-squared
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# -0.5307429472989957

# %% [markdown]
# # OLS linear regression

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(x_train).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model=sm.OLS(x_train).fit()
#
# NameError: name 'x_train' is not defined

# %%
# Prediction for new data

# %%
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(model.summary())
#
# NameError: name 'model' is not defined
